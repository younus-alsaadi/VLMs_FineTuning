# %% [markdown]
# # VLMs_FineTuning + OCR
#
#
# In this project, I will fine-tune a vision-language model (VLM) to accurately extract Arabic text from challenging images. The goal is to improve OCR performance on noisy scans, handwritten/printed text, mixed Arabic/English content, and complex document layouts.

# %%
# !pip install pdf2image==1.17.0 pillow==12.1.0 tqdm
# !apt-get install -y poppler-utils
# !pip install json-repair

# %%
# !pip install litellm==1.73.6
